# %% [markdown]
# # review outputs of analysis pipeline
# ## check_pipeline_outputs.ipynb
#
# This script will open the .json config file used to run the analysis pipeline and the data saved out from the pipeline as .nc files. This notebook also has some examples of how to select data out of the xarray structures opened from .nc files. User only needs to enter a path to the .json config file used and the .nc files will be found from the save-path contained therein. Run this in the ```fmephys``` environment.
#
# Last modified September 07, 2020

# %%
import os.path
import xarray as xr
import pandas as pd

from util.read_data import find

# %% [markdown]
# ## user inputs

# %%
# path to the folder of all xarrays saved out from the trial
parent_path = r'G:\freely_moving_ephys\ephys_recordings\092820\J524RT\outputs_Oct07a'
# the name of the trial to focus on
trial_name = '092820_J524RT_fm1'

# %% [markdown]
# ## pipeline outputs

# %% [markdown]
# ### ephys data

# %%
ephys_path = os.path.join(parent_path, trial_name + '_ephys.json')
ephys_data = pd.read_json(ephys_path)

# %%
ephys_data
# Out:
#     Amplitude  ContamPct KSLabel        amp  ch  depth         fr  group  \
# 0       383.9        8.9    good  31.474401   0      1   9.410262   good
# 1       315.4       39.3     mua  23.014782   0      1   4.292032  noise
# 2       427.5        6.7    good  33.772884   0      1   4.480758   good
# 3       212.9        0.3    good  14.963311   3      4  52.519312  noise
# 4       419.4     7688.6     mua  14.540514   5      6   0.119945  noise
# ..        ...        ...     ...        ...  ..    ...        ...    ...
# 60      227.9       41.4     mua  15.748152  14     15   1.347079  noise
# 61      407.9      433.3     mua  24.803701  12     13   0.102331  noise
# 62      444.9       64.6     mua  28.681179  15     16   1.807569  noise
# 63      880.2        7.3    good  46.786968   5      6   2.664801   good
# 64     1982.9        0.0    good  73.811607   8      9   0.931045   good
#
#     n_spikes  sh                                             spikeT  \
# 0      11219   0  [0.005200000000000001, 0.1723, 0.3153666667, 0...
# 1       5117   0  [0.3441333333, 0.37420000000000003, 0.6085, 0....
# 2       5342   0  [0.2502333333, 0.3950666667, 0.4000333333, 0.4...
# 3      62614   0  [0.0135, 0.0301666667, 0.038666666700000005, 0...
# 4        143   0  [1.2057333333, 1.2063333333, 1.2069333333, 1.2...
# ..       ...  ..                                                ...
# 60      1606   0  [0.1720666667, 1.2078, 1.2083, 1.2083666667, 5...
# 61       122   0  [1.2079666667, 1.2081333333, 4.1210333333, 24....
# 62      2155   0  [0.4181, 1.2067666667, 1.7301666667000002, 4.2...
# 63      3177   0  [0.1915, 0.9548333333000001, 1.2069333333, 1.2...
# 64      1110   0  [1.1519, 4.1536333333, 4.1565, 5.2526, 9.75186...
#
#                                              waveform            t0
# 0   [-0.0043589817, -0.0055342452, -0.0068012639, ...  44440.826854
# 1   [-0.0084317792, -0.0073682186, -0.0058965264, ...  44440.826854
# 2   [7.20132e-05, -0.014391127, -0.010996173100000...  44440.826854
# 3   [-0.0052585383, 0.037936274, 0.0337595865, 0.0...  44440.826854
# 4   [-0.0398195833, -0.040726833000000004, -0.0230...  44440.826854
# ..                                                ...           ...
# 60  [-0.028306337100000002, -0.0157045126, -0.0144...  44440.826854
# 61  [0.0061434517, -0.011211108400000001, -0.01099...  44440.826854
# 62  [0.0123204067, -0.0176212471, -0.010032489, -0...  44440.826854
# 63  [0.0278140716, 0.018410490800000002, 0.0204440...  44440.826854
# 64  [0.0289012734, 0.00034753890000000003, 0.00437...  44440.826854
#
# [63 rows x 13 columns]

# %% [markdown]
# ### eye parameters and properties

# %%
eye_nc_path = ephys_path = os.path.join(parent_path, trial_name + 'Reye.nc')
eye_data = xr.open_dataset(eye_nc_path)
eye_data
# Out:
# <xarray.Dataset>
# Dimensions:              (ellipse_params: 6, frame: 35910, height: 240, point_loc: 30, width: 320)
# Coordinates:
#   * frame                (frame) int64 0 1 2 3 4 ... 35906 35907 35908 35909
#   * point_loc            (point_loc) object 'pt1_x' ... 'outer_likelihood'
#     timestamps           (frame) float64 ...
#   * ellipse_params       (ellipse_params) object 'theta' 'phi' ... 'X0' 'Y0'
# Dimensions without coordinates: height, width
# Data variables:
#     REYE_pts             (frame, point_loc) float64 ...
#     REYE_ellipse_params  (frame, ellipse_params) float64 ...
#     REYE_video           (frame, height, width) int8 ...

# %%
# pull out the original DeepLabCut points
eye_dlc = eye_data['eye_dlc_pts']

# %%
# pull out the ellipse parameters
eye_ellipse = eye_data['eye_ellipse_params']

# %%
# pull out radius of eye at each possible degree
eye_rfit = eye_data['eye_radius_fit']

# %%
# pull out pupil rotation angle in degrees
eye_pupil_rot = eye_data['eye_pupil_rotation']
eye_pupil_rot

# %% [markdown]
# ## example selection and indexing

# %%
# here, we'll grab phi from frame 0 to 100 and plot it for a given trial
phi1d = eye_ellipse.sel(trial='112619_J463b_cricket2clip0',ellipse_params='phi').isel(frame=slice(0,100)).plot()

# %%
# next, we'll plot the angle of rotation of the pupil for those same frames
puprot1d = eye_pupil_rot.sel(trial='112619_J463b_cricket2clip0').isel(frame=slice(0,20)).plot()
