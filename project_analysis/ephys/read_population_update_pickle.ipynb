# %%
import sys
sys.path.insert(0, '/home/niell_lab/Documents/github/FreelyMovingEphys/')
import pandas as pd
import xarray as xr
from population_utils import *

# %%
df1 = pd.read_pickle('/home/niell_lab/data/freely_moving_ephys/batch_files/090821/pooled_ephys_population_update_090821.pickle')

# %%
plt.subplots(3,1,figsize=(10,8))
plt.subplot(3,1,1)
plt.title('gratings spont')
plt.plot(df1['hf3_gratings_drift_spont'])
plt.subplot(3,1,2)
plt.title('gratings evoked')
plt.plot(df1['hf3_gratings_evoked_rate'])
plt.subplot(3,1,3)
plt.title('depth')
plt.plot(df1['hf1_wn_depth_from_layer5'])
plt.tight_layout()

# %%
plt.figure(figsize=(10,4))
plt.plot(df1['hf1_wn_depth_from_layer5'])

# %%
df1['session'][pd.isnull(df1['hf3_gratings_drift_spont'])].unique()
# Out:
# array(['070621_J553LT_control_Rig2', nan], dtype=object)

# %%
for ind, row in df1.iterrows():
    if type(row['fm1_spikeT']) != float:
        df1.at[ind, 'fires_2sp_sec'] = (True if (len(row['fm1_spikeT'])/np.nanmax(row['fm1_eyeT']))>2 else False)
    else:
        df1.at[ind, 'fires_2sp_sec'] = False

# %%
df1['fires_2sp_sec']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 534    False
# 537    False
# 541    False
# 545    False
# 549    False
# Name: fires_2sp_sec, Length: 445, dtype: object

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df1.loc[520])
# Out:
# level_0                                                     NaN
# index                                                       NaN
# Amplitude                                                   NaN
# ContamPct                                                   NaN
# KSLabel                                                     NaN
# amp                                                         NaN
# ch                                                          NaN
# depth                                                       NaN
# fr                                                          NaN
# group                                                       NaN
# fm1_n_spikes                                                NaN
# sh                                                          NaN
# waveform                                                    NaN
# fm1_spikeT                                                  NaN
# t0                                                          NaN
# ...
