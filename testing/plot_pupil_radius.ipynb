# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
data_path = r'D:\data\widefield_eyecams\031121\G6H277RT\hf4_THRESH2\031121_G6H277RT_ThreshPass_Rig2_hf4_THRESH2_Reye.nc'
data = xr.open_dataset(data_path)

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:              (ellipse_params: 7, frame: 19097, height: 240, point_loc: 30, width: 320)
# Coordinates:
#   * frame                (frame) int64 0 1 2 3 4 ... 19093 19094 19095 19096
#   * point_loc            (point_loc) object 'pt1_x' ... 'outer_likelihood'
#   * ellipse_params       (ellipse_params) object 'theta' 'phi' ... 'ellipse_phi'
# Dimensions without coordinates: height, width
# Data variables:
#     REYE_pts             (frame, point_loc) float64 ...
#     REYE_ellipse_params  (frame, ellipse_params) float64 ...
#     REYE_video           (frame, height, width) int8 ...

# %%
data.REYE_ellipse_params.sel(ellipse_params='longaxis', frame=slice(0,3600*2)).plot()
plt.title('031121_G6H277RT_ThreshPass_Rig2_hf4_THRESH2')
plt.ylabel('pupil diameter in pxls'); plt.xlabel('time (s)')
plt.xticks(ticks=np.arange(0,3600*2,1000),labels=range(0,120,int(120/8)))
# Out:
# ([<matplotlib.axis.XTick at 0x1d50e3a4b88>,
# ...
#  <a list of 8 Text xticklabel objects>)

# %%
len(np.arange(0,120,120/8))
# Out:
# 8

# %%
len(np.arange(0,3600*2,1000))
# Out:
# 8
