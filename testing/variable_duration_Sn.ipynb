# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rand = np.load('/home/niell_lab/Desktop/060922_Sn/rand_sn.npz')
cont = np.load('/home/niell_lab/Desktop/060922_Sn/cont_sn.npz')

# %%
rand_on = rand['sn_on']
cont_on = cont['sn_on']

# %%
rand_on.shape
# Out:
# (82, 2001, 4)

# %%
psth_bins = np.arange(-1,1.001,1/1000)

# %%
plt.subplots(9,10,figsize=(25,10),dpi=300)
for i in range(82):
    ax = plt.subplot(9,10,i+1)
    ax.plot(psth_bins, cont_on[i,:,0], 'k-')
    ax.plot(psth_bins, rand_on[i,:,0], 'r-')
    ax.set_xlim([-.3,.3])
plt.tight_layout()
